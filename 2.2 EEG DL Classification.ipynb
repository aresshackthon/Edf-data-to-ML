# %%
import tensorflow as tf

# %%
physical_devices = tf.config.list_physical_devices('GPU')

# %%
from glob import glob
import os
import mne
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#read all file
all_files_path=glob('D:/dataverse_files/*.edf')
print(len(all_files_path))
# Out:
# 28

# %%
all_files_path[0]
# Out:
# 'D:/dataverse_files\\h01.edf'

# %%
healthy_file_path=[i for i in all_files_path if  'h' in i.split('\\')[1]]
patient_file_path=[i for i in all_files_path if  's' in i.split('\\')[1]]

# %%
def read_data(file_path):
    datax=mne.io.read_raw_edf(file_path,preload=True)
    datax.set_eeg_reference()
    datax.filter(l_freq=1,h_freq=45)
    epochs=mne.make_fixed_length_epochs(datax,duration=25,overlap=0)
    epochs=epochs.get_data()
    return epochs #trials,channel,length

# %%
data=read_data(healthy_file_path[0])
# Out:
# Extracting EDF parameters from D:\dataverse_files\h01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 231249  =      0.000 ...   924.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 37 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 37 events and 6250 original time points ...
# 0 bad epochs dropped

# %%
data.shape
# Out:
# (37, 19, 6250)

# %%
control_epochs_array=[read_data(subject) for subject in healthy_file_path]
patients_epochs_array=[read_data(subject) for subject in patient_file_path]
# Out:
# Extracting EDF parameters from D:\dataverse_files\h01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 231249  =      0.000 ...   924.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 37 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 37 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 227499  =      0.000 ...   909.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 36 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 227499  =      0.000 ...   909.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 36 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 231249  =      0.000 ...   924.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 37 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 37 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 236249  =      0.000 ...   944.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 37 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 37 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 232499  =      0.000 ...   929.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 37 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 37 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 227499  =      0.000 ...   909.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 36 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 227499  =      0.000 ...   909.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 36 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 226249  =      0.000 ...   904.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 36 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 278749  =      0.000 ...  1114.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 44 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 44 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 228749  =      0.000 ...   914.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 36 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 224999  =      0.000 ...   899.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 36 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 241249  =      0.000 ...   964.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 38 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 38 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\h14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 216249  =      0.000 ...   864.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 34 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 34 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 211249  =      0.000 ...   844.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 33 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 33 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 286249  =      0.000 ...  1144.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 45 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 45 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 240999  =      0.000 ...   963.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 38 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 38 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 301249  =      0.000 ...  1204.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 222499  =      0.000 ...   889.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 35 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 35 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 184999  =      0.000 ...   739.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 29 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 29 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 336499  =      0.000 ...  1345.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 53 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 53 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 227749  =      0.000 ...   910.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 36 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 296249  =      0.000 ...  1184.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 47 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 47 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 212499  =      0.000 ...   849.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 34 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 34 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 339999  =      0.000 ...  1359.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 54 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 271749  =      0.000 ...  1086.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 43 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 43 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 283749  =      0.000 ...  1134.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 45 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 45 events and 6250 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from D:\dataverse_files\s14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 542499  =      0.000 ...  2169.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Not setting metadata
# Not setting metadata
# 86 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 86 events and 6250 original time points ...
# 0 bad epochs dropped

# %%
control_epochs_labels=[len(i)*[0] for i in control_epochs_array]
patients_epochs_labels=[len(i)*[1] for i in patients_epochs_array]
print(len(control_epochs_labels),len(patients_epochs_labels))
# Out:
# 14 14

# %%
data_list=control_epochs_array+patients_epochs_array
label_list=control_epochs_labels+patients_epochs_labels
print(len(data_list),len(label_list))
# Out:
# 28 28

# %%
groups_list=[[i]*len(j) for i, j in enumerate(data_list)]

# %%
data_array=np.vstack(data_list)
label_array=np.hstack(label_list)
group_array=np.hstack(groups_list)
data_array=np.moveaxis(data_array,1,2)

print(data_array.shape,label_array.shape,group_array.shape)
# Out:
# (1142, 6250, 19) (1142,) (1142,)

# %%
from tensorflow.keras.layers import Conv1D,BatchNormalization,LeakyReLU,MaxPool1D,\
GlobalAveragePooling1D,Dense,Dropout,AveragePooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.backend import clear_session
def cnnmodel():
    clear_session()
    model=Sequential()
    model.add(Conv1D(filters=5,kernel_size=3,strides=1,input_shape=(6250,19)))#1
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPool1D(pool_size=2,strides=2))#2
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#3
    model.add(LeakyReLU())
    model.add(MaxPool1D(pool_size=2,strides=2))#4
    model.add(Dropout(0.5))
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#5
    model.add(LeakyReLU())
    model.add(AveragePooling1D(pool_size=2,strides=2))#6
    model.add(Dropout(0.5))
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#7
    model.add(LeakyReLU())
    model.add(AveragePooling1D(pool_size=2,strides=2))#8
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#9
    model.add(LeakyReLU())
    model.add(GlobalAveragePooling1D())#10
    model.add(Dense(1,activation='sigmoid'))#11
    
    model.compile('adam',loss='binary_crossentropy',metrics=['accuracy'])
    return model

model=cnnmodel()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 6248, 5)           290
#
#  batch_normalization (BatchN  (None, 6248, 5)          20
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 6248, 5)           0
#
#  max_pooling1d (MaxPooling1D  (None, 3124, 5)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 3122, 5)           80
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 3122, 5)           0
#
#  max_pooling1d_1 (MaxPooling  (None, 1561, 5)          0
#  1D)
#
#  dropout (Dropout)           (None, 1561, 5)           0
#
#  conv1d_2 (Conv1D)           (None, 1559, 5)           80
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 1559, 5)           0
#
#  average_pooling1d (AverageP  (None, 779, 5)           0
#  ooling1D)
#
#  dropout_1 (Dropout)         (None, 779, 5)            0
#
#  conv1d_3 (Conv1D)           (None, 777, 5)            80
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 777, 5)            0
#
#  average_pooling1d_1 (Averag  (None, 388, 5)           0
#  ePooling1D)
#
#  conv1d_4 (Conv1D)           (None, 386, 5)            80
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 386, 5)            0
#
#  global_average_pooling1d (G  (None, 5)                0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 636
# Trainable params: 626
# Non-trainable params: 10
# _________________________________________________________________

# %%
from sklearn.model_selection import GroupKFold,LeaveOneGroupOut
from sklearn.preprocessing import StandardScaler
gkf=GroupKFold()

# %%
accuracy=[]
for train_index, val_index in gkf.split(data_array, label_array, groups=group_array):
    train_features,train_labels=data_array[train_index],label_array[train_index]
    val_features,val_labels=data_array[val_index],label_array[val_index]
    scaler=StandardScaler()
    train_features = scaler.fit_transform(train_features.reshape(-1, train_features.shape[-1])).reshape(train_features.shape)
    val_features = scaler.transform(val_features.reshape(-1, val_features.shape[-1])).reshape(val_features.shape)
    model=cnnmodel()
    model.fit(train_features,train_labels,epochs=50,batch_size=128,validation_data=(val_features,val_labels))
    accuracy.append(model.evaluate(val_features,val_labels)[1])
# Out:
# Epoch 1/50
# 8/8 [==============================] - 3s 262ms/step - loss: 0.6990 - accuracy: 0.4852 - val_loss: 0.7122 - val_accuracy: 0.2900
# Epoch 2/50
# 8/8 [==============================] - 2s 234ms/step - loss: 0.6937 - accuracy: 0.4896 - val_loss: 0.6848 - val_accuracy: 0.6797
# Epoch 3/50
# 8/8 [==============================] - 2s 229ms/step - loss: 0.6908 - accuracy: 0.5126 - val_loss: 0.6712 - val_accuracy: 0.6840
# Epoch 4/50
# 8/8 [==============================] - 2s 242ms/step - loss: 0.6902 - accuracy: 0.5137 - val_loss: 0.6644 - val_accuracy: 0.6840
# Epoch 19/50
# 8/8 [==============================] - 2s 249ms/step - loss: 0.5060 - accuracy: 0.8161 - val_loss: 0.6679 - val_accuracy: 0.6239
# Epoch 20/50
# 8/8 [==============================] - 2s 227ms/step - loss: 0.4727 - accuracy: 0.8095 - val_loss: 0.6670 - val_accuracy: 0.5940
# Epoch 21/50
# 8/8 [==============================] - 2s 249ms/step - loss: 0.4605 - accuracy: 0.8029 - val_loss: 0.6788 - val_accuracy: 0.5983
# Epoch 22/50
# 8/8 [==============================] - 2s 270ms/step - loss: 0.4216 - accuracy: 0.8271 - val_loss: 0.7101 - val_accuracy: 0.6453
# Epoch 23/50
# 8/8 [==============================] - 3s 309ms/step - loss: 0.3816 - accuracy: 0.8480 - val_loss: 0.7142 - val_accuracy: 0.6197
# Epoch 24/50
# 8/8 [==============================] - 2s 311ms/step - loss: 0.3695 - accuracy: 0.8535 - val_loss: 0.7500 - val_accuracy: 0.6368
# Epoch 25/50
# 8/8 [==============================] - 2s 307ms/step - loss: 0.3402 - accuracy: 0.8656 - val_loss: 0.7850 - val_accuracy: 0.6368
# Epoch 26/50
# 8/8 [==============================] - 2s 261ms/step - loss: 0.3196 - accuracy: 0.8645 - val_loss: 0.8997 - val_accuracy: 0.6453
# Epoch 27/50
# 8/8 [==============================] - 2s 296ms/step - loss: 0.3061 - accuracy: 0.8789 - val_loss: 0.9454 - val_accuracy: 0.6496
# Epoch 28/50
# 8/8 [==============================] - 2s 248ms/step - loss: 0.2895 - accuracy: 0.8833 - val_loss: 1.0334 - val_accuracy: 0.6325
# Epoch 29/50
# 8/8 [==============================] - 2s 238ms/step - loss: 0.2633 - accuracy: 0.8998 - val_loss: 0.9465 - val_accuracy: 0.6496
# Epoch 30/50
# 8/8 [==============================] - 2s 253ms/step - loss: 0.2496 - accuracy: 0.9031 - val_loss: 1.0808 - val_accuracy: 0.6197
# Epoch 31/50
# 8/8 [==============================] - 2s 295ms/step - loss: 0.2402 - accuracy: 0.9009 - val_loss: 1.0588 - val_accuracy: 0.6453
# Epoch 32/50
# 8/8 [==============================] - 2s 242ms/step - loss: 0.2505 - accuracy: 0.8998 - val_loss: 1.0290 - val_accuracy: 0.6667
# Epoch 33/50
# 8/8 [==============================] - 2s 240ms/step - loss: 0.2567 - accuracy: 0.8921 - val_loss: 1.0931 - val_accuracy: 0.6538
# Epoch 34/50
# 8/8 [==============================] - 2s 235ms/step - loss: 0.2159 - accuracy: 0.9174 - val_loss: 1.3605 - val_accuracy: 0.5983
# Epoch 35/50
# 8/8 [==============================] - 2s 232ms/step - loss: 0.2189 - accuracy: 0.9251 - val_loss: 1.2086 - val_accuracy: 0.6325
# Epoch 36/50
# 8/8 [==============================] - 2s 233ms/step - loss: 0.2003 - accuracy: 0.9306 - val_loss: 1.0699 - val_accuracy: 0.6667
# Epoch 37/50
# 8/8 [==============================] - 2s 228ms/step - loss: 0.1937 - accuracy: 0.9218 - val_loss: 1.1368 - val_accuracy: 0.6453
# Epoch 38/50
# 8/8 [==============================] - 2s 228ms/step - loss: 0.1976 - accuracy: 0.9251 - val_loss: 1.2899 - val_accuracy: 0.6282
# Epoch 39/50
# 8/8 [==============================] - 2s 225ms/step - loss: 0.1907 - accuracy: 0.9262 - val_loss: 1.3726 - val_accuracy: 0.6197
# Epoch 40/50
# 8/8 [==============================] - 2s 228ms/step - loss: 0.1814 - accuracy: 0.9306 - val_loss: 1.5429 - val_accuracy: 0.5812
# Epoch 41/50
# 8/8 [==============================] - 2s 226ms/step - loss: 0.1634 - accuracy: 0.9482 - val_loss: 1.4608 - val_accuracy: 0.6026
# Epoch 42/50
# 8/8 [==============================] - 2s 227ms/step - loss: 0.1688 - accuracy: 0.9394 - val_loss: 1.3370 - val_accuracy: 0.6325
# Epoch 43/50
# 8/8 [==============================] - 2s 224ms/step - loss: 0.1780 - accuracy: 0.9328 - val_loss: 1.4303 - val_accuracy: 0.6111
# Epoch 44/50
# 8/8 [==============================] - 2s 226ms/step - loss: 0.1660 - accuracy: 0.9394 - val_loss: 1.6290 - val_accuracy: 0.5470
# Epoch 45/50
# 8/8 [==============================] - 2s 226ms/step - loss: 0.1487 - accuracy: 0.9405 - val_loss: 1.3082 - val_accuracy: 0.6111
# Epoch 46/50
# 8/8 [==============================] - 2s 225ms/step - loss: 0.1499 - accuracy: 0.9471 - val_loss: 1.4298 - val_accuracy: 0.5641
# Epoch 47/50
# 8/8 [==============================] - 2s 238ms/step - loss: 0.1485 - accuracy: 0.9570 - val_loss: 1.6441 - val_accuracy: 0.5256
# Epoch 48/50
# 8/8 [==============================] - 2s 230ms/step - loss: 0.1330 - accuracy: 0.9482 - val_loss: 1.8784 - val_accuracy: 0.5256
# Epoch 49/50
# 8/8 [==============================] - 2s 228ms/step - loss: 0.1257 - accuracy: 0.9604 - val_loss: 1.5311 - val_accuracy: 0.5427
# Epoch 50/50
# 8/8 [==============================] - 2s 222ms/step - loss: 0.1358 - accuracy: 0.9537 - val_loss: 1.7994 - val_accuracy: 0.5256
# 8/8 [==============================] - 0s 14ms/step - loss: 1.7994 - accuracy: 0.5256
# Epoch 1/50
# 8/8 [==============================] - 3s 261ms/step - loss: 0.6891 - accuracy: 0.5397 - val_loss: 0.6926 - val_accuracy: 0.5466
# Epoch 2/50
# 8/8 [==============================] - 2s 234ms/step - loss: 0.6834 - accuracy: 0.5486 - val_loss: 0.6927 - val_accuracy: 0.5466
# Epoch 3/50
# 8/8 [==============================] - 2s 233ms/step - loss: 0.6790 - accuracy: 0.5486 - val_loss: 0.6928 - val_accuracy: 0.5466
# Epoch 4/50
# 8/8 [==============================] - 2s 234ms/step - loss: 0.6730 - accuracy: 0.5486 - val_loss: 0.6934 - val_accuracy: 0.5466
# Epoch 5/50
# 8/8 [==============================] - 2s 256ms/step - loss: 0.6699 - accuracy: 0.5486 - val_loss: 0.6946 - val_accuracy: 0.5466
# Epoch 6/50
# 8/8 [==============================] - 2s 248ms/step - loss: 0.6601 - accuracy: 0.5524 - val_loss: 0.6693 - val_accuracy: 0.5319
# Epoch 14/50
# 8/8 [==============================] - 2s 250ms/step - loss: 0.6628 - accuracy: 0.5524 - val_loss: 0.6697 - val_accuracy: 0.5319
# Epoch 15/50
# 8/8 [==============================] - 2s 252ms/step - loss: 0.6599 - accuracy: 0.5524 - val_loss: 0.6675 - val_accuracy: 0.5319
# Epoch 16/50
# 8/8 [==============================] - 2s 267ms/step - loss: 0.6583 - accuracy: 0.5524 - val_loss: 0.6666 - val_accuracy: 0.5319
# Epoch 17/50
# 8/8 [==============================] - 2s 282ms/step - loss: 0.6571 - accuracy: 0.5502 - val_loss: 0.6647 - val_accuracy: 0.5532
# Epoch 18/50
# 8/8 [==============================] - 2s 285ms/step - loss: 0.6534 - accuracy: 0.5535 - val_loss: 0.6600 - val_accuracy: 0.5702
# Epoch 19/50
# 8/8 [==============================] - 2s 276ms/step - loss: 0.6440 - accuracy: 0.5546 - val_loss: 0.6559 - val_accuracy: 0.7191
# Epoch 20/50
# 8/8 [==============================] - 2s 277ms/step - loss: 0.6399 - accuracy: 0.5645 - val_loss: 0.6469 - val_accuracy: 0.8851
# Epoch 21/50
# 8/8 [==============================] - 2s 279ms/step - loss: 0.6383 - accuracy: 0.5711 - val_loss: 0.6353 - val_accuracy: 0.9191
# Epoch 22/50
# 8/8 [==============================] - 2s 276ms/step - loss: 0.6283 - accuracy: 0.5843 - val_loss: 0.6336 - val_accuracy: 0.8894
# Epoch 23/50
# 8/8 [==============================] - 2s 279ms/step - loss: 0.6195 - accuracy: 0.6307 - val_loss: 0.6327 - val_accuracy: 0.6638
# Epoch 24/50
# 8/8 [==============================] - 2s 281ms/step - loss: 0.6119 - accuracy: 0.6494 - val_loss: 0.6318 - val_accuracy: 0.5915
# Epoch 25/50
# 8/8 [==============================] - 2s 270ms/step - loss: 0.6046 - accuracy: 0.7012 - val_loss: 0.6104 - val_accuracy: 0.6255
# Epoch 26/50
# 8/8 [==============================] - 2s 245ms/step - loss: 0.5943 - accuracy: 0.7001 - val_loss: 0.6172 - val_accuracy: 0.5915
# Epoch 27/50
# 8/8 [==============================] - 2s 244ms/step - loss: 0.5851 - accuracy: 0.6957 - val_loss: 0.5805 - val_accuracy: 0.6553
# Epoch 28/50
# 8/8 [==============================] - 2s 253ms/step - loss: 0.5601 - accuracy: 0.7266 - val_loss: 0.5545 - val_accuracy: 0.7362
# Epoch 29/50
# 8/8 [==============================] - 2s 258ms/step - loss: 0.5499 - accuracy: 0.7398 - val_loss: 0.5402 - val_accuracy: 0.7234
# Epoch 30/50
# 8/8 [==============================] - 2s 247ms/step - loss: 0.5284 - accuracy: 0.7674 - val_loss: 0.4984 - val_accuracy: 0.8383
# Epoch 31/50
# 8/8 [==============================] - 2s 245ms/step - loss: 0.5229 - accuracy: 0.7630 - val_loss: 0.4558 - val_accuracy: 0.9149
# Epoch 32/50
# 8/8 [==============================] - 2s 257ms/step - loss: 0.5276 - accuracy: 0.7244 - val_loss: 0.5016 - val_accuracy: 0.7021
# Epoch 33/50
# 8/8 [==============================] - 2s 250ms/step - loss: 0.4986 - accuracy: 0.7530 - val_loss: 0.4290 - val_accuracy: 0.9404
# Epoch 34/50
# 8/8 [==============================] - 2s 252ms/step - loss: 0.4981 - accuracy: 0.7596 - val_loss: 0.4055 - val_accuracy: 0.9745
# Epoch 35/50
# 8/8 [==============================] - 2s 250ms/step - loss: 0.4702 - accuracy: 0.8049 - val_loss: 0.4204 - val_accuracy: 0.9362
# Epoch 36/50
# 8/8 [==============================] - 2s 247ms/step - loss: 0.4759 - accuracy: 0.7707 - val_loss: 0.4166 - val_accuracy: 0.9319
# Epoch 37/50
# 8/8 [==============================] - 2s 247ms/step - loss: 0.4507 - accuracy: 0.7993 - val_loss: 0.3757 - val_accuracy: 0.9532
# Epoch 38/50
# 8/8 [==============================] - 2s 247ms/step - loss: 0.4436 - accuracy: 0.8126 - val_loss: 0.3512 - val_accuracy: 0.9574
# Epoch 39/50
# 8/8 [==============================] - 2s 253ms/step - loss: 0.4367 - accuracy: 0.8126 - val_loss: 0.3615 - val_accuracy: 0.9277
# Epoch 40/50
# 8/8 [==============================] - 2s 253ms/step - loss: 0.4524 - accuracy: 0.7574 - val_loss: 0.3573 - val_accuracy: 0.9404
# Epoch 41/50
# 8/8 [==============================] - 2s 248ms/step - loss: 0.4354 - accuracy: 0.8004 - val_loss: 0.3233 - val_accuracy: 0.9489
# Epoch 42/50
# 8/8 [==============================] - 2s 247ms/step - loss: 0.4214 - accuracy: 0.8115 - val_loss: 0.3226 - val_accuracy: 0.9574
# Epoch 43/50
# 8/8 [==============================] - 2s 246ms/step - loss: 0.4046 - accuracy: 0.8280 - val_loss: 0.3197 - val_accuracy: 0.9617
# Epoch 44/50
# 8/8 [==============================] - 2s 252ms/step - loss: 0.4037 - accuracy: 0.8291 - val_loss: 0.3107 - val_accuracy: 0.9106
# Epoch 45/50
# 8/8 [==============================] - 2s 247ms/step - loss: 0.4035 - accuracy: 0.8247 - val_loss: 0.3139 - val_accuracy: 0.9447
# Epoch 46/50
# 8/8 [==============================] - 2s 247ms/step - loss: 0.4164 - accuracy: 0.8247 - val_loss: 0.3068 - val_accuracy: 0.9447
# Epoch 47/50
# 8/8 [==============================] - 2s 257ms/step - loss: 0.3817 - accuracy: 0.8368 - val_loss: 0.3079 - val_accuracy: 0.8681
# Epoch 48/50
# 8/8 [==============================] - 2s 248ms/step - loss: 0.3864 - accuracy: 0.8412 - val_loss: 0.2934 - val_accuracy: 0.9064
# Epoch 49/50
# 8/8 [==============================] - 2s 247ms/step - loss: 0.3662 - accuracy: 0.8434 - val_loss: 0.2882 - val_accuracy: 0.9489
# Epoch 50/50
# 8/8 [==============================] - 2s 241ms/step - loss: 0.3511 - accuracy: 0.8622 - val_loss: 0.2887 - val_accuracy: 0.9064
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2887 - accuracy: 0.9064

# %%
np.mean(accuracy)
# Out:
# 0.6696985721588135
